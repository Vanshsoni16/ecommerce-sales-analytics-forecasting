# %%
import pandas as pd
import numpy as np
from pathlib import Path

# %%
df= pd.read_csv(
    r"C:\Users\vansh soni\PROJECT_2\data\raw\ecommerce_sales_data.csv"
)

# %%
# Dataset Overview
print("Dataset Shape:", df.shape)

print("\nMissing Values:")
print(df.isnull().sum())

print("\nDuplicate Records:")
print(df.duplicated().sum())

# Remove Duplicates
df = df.drop_duplicates()

# Convert Date Column
df["Order Date"] = pd.to_datetime(df["Order Date"])

# Category Analysis
print("\nSales by Category")
print(
    df.groupby("Category")["Sales"]
    .sum()
)

# Region Analysis
print("\nSales by Region")
print(
    df.groupby("Region")["Sales"]
    .sum()
)

# Profit Analysis
print("\nProfit by Region")
print(
    df.groupby("Region")["Profit"]
    .sum()
)

# Top Products
print("\nTop Products")
print(
    df.groupby("Product Name")["Sales"]
    .sum()
    .sort_values(ascending=False)
    .head(10)
)

# Monthly Sales
monthly_sales = (
    df.resample(
        "MS",
        on="Order Date"
    )["Sales"]
    .sum()
)

print("\nMonthly Sales")
print(monthly_sales.head())

# Create Processed Folder
processed_folder = Path("../data/processed")

processed_folder.mkdir(
    parents=True,
    exist_ok=True
)

# Save Cleaned Dataset
df.to_csv(
    processed_folder / "cleaned_sales.csv",
    index=False
)

print("\n✅ cleaned_sales.csv saved successfully!")
# Out:
# Dataset Shape: (3500, 13)
#
# Missing Values:
# Order Date       0
# Product Name     0
# Category         0
# Region           0
# Quantity         0
# Sales            0
# Profit           0
# Year             0
# Month            0
# Month Name       0
# Quarter          0
# Day Name         0
# Profit Margin    0
# dtype: int64
#
# Duplicate Records:
# 0
#
# Sales by Category
# Category
# Accessories    4247591
# Electronics    5326074
# Office         1094216
# Name: Sales, dtype: int64
#
# Sales by Region
# Region
# East     2675110
# North    2488773
# South    2659548
# West     2844450
# Name: Sales, dtype: int64
#
# Profit by Region
# Region
# East     464888.46
# North    426314.75
# South    458103.27
# West     495358.73
# Name: Profit, dtype: float64
#
# Top Products
# Product Name
# Camera        1177381
# Monitor       1160048
# Printer       1094216
# Mouse         1074398
# Smartphone    1069681
# Smartwatch    1049211
# Keyboard      1024507
# Tablet        1023928
# Laptop        1005873
# Headphones     988638
# Name: Sales, dtype: int64
#
# Monthly Sales
# Order Date
# 2022-01-01    341544
# 2022-02-01    208775
# 2022-03-01    294660
# 2022-04-01    230624
# 2022-05-01    314295
# Freq: MS, Name: Sales, dtype: int64
#
# ✅ cleaned_sales.csv saved successfully!

# %%
# Out:
#    Order Date Product Name     Category Region  Quantity  Sales  Profit  Year  \
# 0  2024-12-31      Printer       Office  North         4   3640  348.93  2024
# 1  2022-11-27        Mouse  Accessories   East         7   1197  106.53  2022
# 2  2022-05-11       Tablet  Electronics  South         5   5865  502.73  2022
# 3  2024-03-16        Mouse  Accessories  South         2    786  202.87  2024
# 4  2022-09-10        Mouse  Accessories   West         1    509  103.28  2022
#
#    Month Month Name  Quarter   Day Name  Profit Margin
# 0     12   December        4    Tuesday       9.585989
# 1     11   November        4     Sunday       8.899749
# 2      5        May        2  Wednesday       8.571697
# 3      3      March        1   Saturday      25.810433
# 4      9  September        3   Saturday      20.290766
